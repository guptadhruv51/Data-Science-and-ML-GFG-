# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Sugarcane_Production.csv",index_col='Unnamed: 0')
df.head()
# Out:
#     Country      Continent Production (Tons) Production per Person (Kg)  \
# 0    Brazil  South America       768.678.382                  3.668,531
# 1     India           Asia       348.448.000                     260721
# 2     China           Asia       123.059.739                      88287
# 3  Thailand           Asia        87.468.496                  1.264,303
# 4  Pakistan           Asia        65.450.704                     324219
#
#   Acreage (Hectare) Yield (Kg / Hectare)
# 0        10.226.205             75.167,5
# 1         4.950.000             70.393,5
# 2         1.675.215             73.459,1
# 3         1.336.575             65.442,2
# 4         1.130.820               57.879

# %%
df.shape
# Out:
# (103, 6)

# %%
df.describe()
# Out:
#        Country Continent Production (Tons) Production per Person (Kg)  \
# count      103       103               103                        103
# unique     103         6               103                        102
# top     Brazil    Africa       768.678.382                        297
# freq         1        39                 1                          2
#
#        Acreage (Hectare) Yield (Kg / Hectare)
# count                102                  102
# unique               102                  102
# top           10.226.205             75.167,5
# freq                   1                    1

# %% [markdown]
# ### Data Cleaning

# %%
df['Production (Tons)']= df['Production (Tons)'].str.replace(".","")
df['Production per Person (Kg)']= df['Production per Person (Kg)'].str.replace(".","").str.replace(",",".")
df['Acreage (Hectare)']= df['Acreage (Hectare)'].str.replace(".","")
df['Yield (Kg / Hectare)']= df['Yield (Kg / Hectare)'].str.replace(".","").str.replace(",",".")
# Out:
# /var/folders/9j/1q09yf3j4mnfpyg5trq4zysr0000gn/T/ipykernel_76359/3263157285.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Production (Tons)']= df['Production (Tons)'].str.replace(".","")
# /var/folders/9j/1q09yf3j4mnfpyg5trq4zysr0000gn/T/ipykernel_76359/3263157285.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Production per Person (Kg)']= df['Production per Person (Kg)'].str.replace(".","").str.replace(",",".")
# /var/folders/9j/1q09yf3j4mnfpyg5trq4zysr0000gn/T/ipykernel_76359/3263157285.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Acreage (Hectare)']= df['Acreage (Hectare)'].str.replace(".","")
# /var/folders/9j/1q09yf3j4mnfpyg5trq4zysr0000gn/T/ipykernel_76359/3263157285.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Yield (Kg / Hectare)']= df['Yield (Kg / Hectare)'].str.replace(".","").str.replace(",",".")

# %%
df.rename(columns= {"Production (Tons)": "Production(Tons)"}, inplace = True)
df.rename(columns= {"Production per Person (Kg)": "Production_per_person(Kg)"}, inplace = True)
df.rename(columns= {"Acreage (Hectare)": "Acreage(Hectare)"}, inplace = True)
df.rename(columns= {"Yield (Kg / Hectare)": "Yield(Kg/Hectare)"}, inplace = True)

# %%
df.isna().sum()
# Out:
# Country                      0
# Continent                    0
# Production(Tons)             0
# Production_per_person(Kg)    0
# Acreage(Hectare)             1
# Yield(Kg/Hectare)            1
# dtype: int64

# %%
df[df['Acreage(Hectare)'].isnull()]
# Out:
#      Country Continent Production(Tons) Production_per_person(Kg)  \
# 99  Djibouti    Africa               53                        51
#
#    Acreage(Hectare) Yield(Kg/Hectare)
# 99              NaN               NaN

# %%
df=df.dropna().reset_index()

# %%
df.drop("index",axis=1,inplace=True)

# %%
df.head()
# Out:
#     Country      Continent Production(Tons) Production_per_person(Kg)  \
# 0    Brazil  South America        768678382                  3668.531
# 1     India           Asia        348448000                    260721
# 2     China           Asia        123059739                     88287
# 3  Thailand           Asia         87468496                  1264.303
# 4  Pakistan           Asia         65450704                    324219
#
#   Acreage(Hectare) Yield(Kg/Hectare)
# 0         10226205           75167.5
# 1          4950000           70393.5
# 2          1675215           73459.1
# 3          1336575           65442.2
# 4          1130820             57879

# %%
df.dtypes
# Out:
# Country                      object
# Continent                    object
# Production(Tons)             object
# Production_per_person(Kg)    object
# Acreage(Hectare)             object
# Yield(Kg/Hectare)            object
# dtype: object

# %%
df["Production(Tons)"] = df["Production(Tons)"].astype(float)
df["Production_per_person(Kg)"] = df["Production_per_person(Kg)"].astype(float)
df["Acreage(Hectare)"] = df["Acreage(Hectare)"].astype(float)
df["Yield(Kg/Hectare)"] = df["Yield(Kg/Hectare)"].astype(float)

# %%
df.dtypes
# Out:
# Country                       object
# Continent                     object
# Production(Tons)             float64
# Production_per_person(Kg)    float64
# Acreage(Hectare)             float64
# Yield(Kg/Hectare)            float64
# dtype: object

# %%
df.nunique()
# Out:
# Country                      102
# Continent                      6
# Production(Tons)             102
# Production_per_person(Kg)    101
# Acreage(Hectare)             101
# Yield(Kg/Hectare)            102
# dtype: int64

# %% [markdown]
# ### Univariate Analysis

# %%
df['Continent'].value_counts()
# Out:
# Africa           38
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: Continent, dtype: int64

# %%
df['Continent'].value_counts().plot(kind='bar')
plt.xlabel('Countries')
# Out:
# Text(0.5, 0, 'Countries')

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.distplot(df["Production(Tons)"])
plt.subplot(2,2,2)
sns.distplot(df["Production_per_person(Kg)"])
plt.subplot(2,2,3)
sns.distplot(df["Acreage(Hectare)"])
plt.subplot(2,2,4)
sns.distplot(df['Yield(Kg/Hectare)'])
# Out:
# /Users/dhruvgupta/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/dhruvgupta/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/dhruvgupta/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/dhruvgupta/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Yield(Kg/Hectare)', ylabel='Density'>

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.boxplot(df["Production(Tons)"])
plt.subplot(2,2,2)
sns.boxplot(df["Production_per_person(Kg)"])
plt.subplot(2,2,3)
sns.boxplot(df["Acreage(Hectare)"])
plt.subplot(2,2,4)
sns.boxplot(df['Yield(Kg/Hectare)'])
# Out:
# /Users/dhruvgupta/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/dhruvgupta/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/dhruvgupta/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/dhruvgupta/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Yield(Kg/Hectare)'>

# %%
df.describe()
# Out:
#        Production(Tons)  Production_per_person(Kg)  Acreage(Hectare)  \
# count      1.020000e+02                 102.000000      1.020000e+02
# mean       1.850372e+07              112952.435755      2.498981e+05
# std        8.419149e+07              176651.341929      1.137003e+06
# min        1.000000e+00                   0.000000      0.000000e+00
# 25%        6.251875e+04                3671.910000      1.104000e+03
# 50%        1.440044e+06               25572.500000      1.655800e+04
# 75%        6.426824e+06              146384.750000      8.047400e+04
# max        7.686784e+08              951087.000000      1.022620e+07
#
#        Yield(Kg/Hectare)
# count         102.000000
# mean        52628.078431
# std         30504.676683
# min            10.000000
# 25%         29072.025000
# 50%         54108.950000
# 75%         73282.700000
# max        129049.300000

# %% [markdown]
# ### Bivariate Analysis

# %%
df_new=df[["Country","Production(Tons)"]].set_index("Country")

# %%
df_new["Production(Tons)_Percentage"]=(df_new['Production(Tons)']*100)/(df['Production(Tons)'].sum())

# %%
df_new.head()
# Out:
#           Production(Tons)  Production(Tons)_Percentage
# Country
# Brazil         768678382.0                    40.727285
# India          348448000.0                    18.462001
# China          123059739.0                     6.520138
# Thailand        87468496.0                     4.634389
# Pakistan        65450704.0                     3.467809

# %%
plt.figure(figsize=(7,7))
df_new["Production(Tons)_Percentage"].plot(kind="pie",autopct="%.2f")
# Out:
# <AxesSubplot:ylabel='Production(Tons)_Percentage'>

# %%
df_new["Production(Tons)"][:10].plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Country'>

# %%
df_acr = df.sort_values("Acreage(Hectare)", ascending = False).head(15)
ax = sns.barplot(data = df_acr,  x= "Country", y = "Acreage(Hectare)")
ax.set_xticklabels(ax.get_xticklabels(),rotation =90)
plt.show()

# %%
df_yield = df.sort_values("Yield(Kg/Hectare)", ascending = False).head(15)
ax = sns.barplot(data = df_yield,  x= "Country", y = "Yield(Kg/Hectare)")
ax.set_xticklabels(ax.get_xticklabels(),rotation =90)
plt.show()

# %%
df_yield = df.sort_values("Production_per_person(Kg)", ascending = False).head(15)
ax = sns.barplot(data = df_yield,  x= "Country", y = "Production_per_person(Kg)")
ax.set_xticklabels(ax.get_xticklabels(),rotation =90)
plt.show()

# %%
df.corr()
# Out:
#                            Production(Tons)  Production_per_person(Kg)  \
# Production(Tons)                   1.000000                   0.015000
# Production_per_person(Kg)          0.015000                   1.000000
# Acreage(Hectare)                   0.997550                   0.012557
# Yield(Kg/Hectare)                  0.132812                   0.017999
#
#                            Acreage(Hectare)  Yield(Kg/Hectare)
# Production(Tons)                   0.997550           0.132812
# Production_per_person(Kg)          0.012557           0.017999
# Acreage(Hectare)                   1.000000           0.113433
# Yield(Kg/Hectare)                  0.113433           1.000000

# %%
sns.heatmap(df.corr(), annot = True, cmap="Greens")
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(data = df, x = "Acreage(Hectare)", y = "Production(Tons)", hue = "Continent" )
# Out:
# <AxesSubplot:xlabel='Acreage(Hectare)', ylabel='Production(Tons)'>

# %%
sns.scatterplot(data = df, x = "Yield(Kg/Hectare)" , y = "Production(Tons)", hue = "Continent")
# Out:
# <AxesSubplot:xlabel='Yield(Kg/Hectare)', ylabel='Production(Tons)'>

# %%
df_continent = df.groupby("Continent").sum()

# %%
df_continent["number_of_countries"] = df.groupby("Continent").count()["Country"]

# %%
df_continent.sort_values("Production(Tons)",ascending=False)
# Out:
#                Production(Tons)  Production_per_person(Kg)  Acreage(Hectare)  \
# Continent
# South America       865588126.0                3505531.738        11369236.0
# Asia                721930425.0                1857769.303        10608319.0
# North America       173995947.0                3796081.508         1581983.0
# Africa               89681472.0                2332636.293         1439089.0
# Oceania              36177574.0                  28593.605          490909.0
# Europe                   5823.0                    536.000              71.0
#
#                Yield(Kg/Hectare)  number_of_countries
# Continent
# South America           677192.7                   11
# Asia                   1171871.4                   25
# North America          1082602.4                   22
# Africa                 2142107.5                   38
# Oceania                 162419.1                    4
# Europe                  131870.9                    2

# %%
continent_names = df_continent.index.to_list()
sns.lineplot(data = df_continent,x = "number_of_countries", y= "Production(Tons)" )
plt.xticks(df_continent["number_of_countries"], continent_names, rotation =90)
plt.show()

# %%
sns.lineplot(data = df_continent,x = "Acreage(Hectare)", y= "Production(Tons)" )
# Out:
# <AxesSubplot:xlabel='Acreage(Hectare)', ylabel='Production(Tons)'>

# %%
df_continent["Production(Tons)"].plot(kind = "pie", autopct = "%.2f%%")
plt.title('Production Distribution by Continent')
plt.show()

# %%
df_continent.corr()
# Out:
#                            Production(Tons)  Production_per_person(Kg)  \
# Production(Tons)                   1.000000                   0.522211
# Production_per_person(Kg)          0.522211                   1.000000
# Acreage(Hectare)                   0.994897                   0.463215
# Yield(Kg/Hectare)                  0.091201                   0.542961
# number_of_countries                0.109244                   0.540086
#
#                            Acreage(Hectare)  Yield(Kg/Hectare)  \
# Production(Tons)                   0.994897           0.091201
# Production_per_person(Kg)          0.463215           0.542961
# Acreage(Hectare)                   1.000000           0.111166
# Yield(Kg/Hectare)                  0.111166           1.000000
# number_of_countries                0.132817           0.989712
#
#                            number_of_countries
# Production(Tons)                      0.109244
# Production_per_person(Kg)             0.540086
# Acreage(Hectare)                      0.132817
# Yield(Kg/Hectare)                     0.989712
# number_of_countries                   1.000000
